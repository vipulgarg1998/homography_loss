# %%
import matplotlib.pyplot as plt
import numpy as np

imgs_data = np.load("intensity_data.npy")
errors_arr = imgs_data[:,1].astype(np.float)
mean_int_arr = imgs_data[:, 2].astype(np.float)
plt.scatter(mean_int_arr, errors_arr)
plt.xlabel("Mean Intensity (Normalized)")
plt.ylabel("Mean Square Reprojection Error")
plt.grid()
# plt.show()
